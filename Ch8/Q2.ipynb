# %% [markdown]
# ### Q2. Draw two different neural network architectures that can guarantee to memorize the training data of a 12-instance binary classification problem of 4-dimensional inputs (assuming perfect training).

# %% [markdown]
# Both the drawings follow a similar architecture: <br>
# <li> Input Layer: 4 neurons (one for each dimension), labelled X1, X2, X3, X4.
# <li> Hidden Layer: arbitrary choice
# <li> Output Layer: 1 neuron (binary classification)

# %% [markdown]
# ![IMG_20240313_174605__01.jpg](attachment:IMG_20240313_174605__01.jpg)
